# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# Términos y definiciones del Curso 1, Módulo 1
# Automatización: el proceso de reemplazar un paso manual por uno que ocurre automáticamente.
#
# Lenguaje de scripting del lado del cliente: principalmente para programación web; Los scripts se transfieren desde un servidor web al navegador de Internet del usuario final y luego se ejecutan en el navegador.
#
# Editores de código: herramientas para proporcionar funciones, incluido resaltado de sintaxis, sangría automática, verificación de errores y autocompletado.
#
# Programa de computadora: una lista paso a paso de instrucciones que sigue una computadora para alcanzar un objetivo previsto.
#
# Funciones: un bloque de código reutilizable que realiza una tarea específica.
#
# IDE: una aplicación de software que proporciona instalaciones integrales para el desarrollo de software.
#
# Intérprete: el programa que lee y ejecuta código.
#
# Entrada: información que el usuario final proporciona a un programa.
#
# Errores lógicos: errores en el código que impiden que se ejecute correctamente
#
# Lenguaje de máquina: lenguaje informático de nivel más bajo. Se comunica directamente con las máquinas informáticas en código binario (unos y ceros).
#
# Lenguaje de programación orientado a objetos: la mayoría de los elementos de codificación se consideran objetos con propiedades configurables.
#
# Salida: el resultado final de una tarea realizada por una función o programa de computadora
#
# Lenguaje de secuencias de comandos específico de la plataforma: lenguaje utilizado por los administradores del sistema en esas plataformas específicas.
#
# Programación: El proceso de escribir un programa para que se comporte de diferentes maneras.
#
# Código de programación : conjunto de instrucciones informáticas escritas, guiadas por reglas, que utilizan un lenguaje de programación informática.
#
# Lenguajes de programación: Lenguaje con sintaxis y semántica para escribir programas informáticos.
#
# Python: un lenguaje de programación de propósito general
#
# Intérprete de Python: programa que lee y ejecuta código Python traduciendo el código Python en instrucciones de computadora.
#
# Script: A menudo se utiliza para automatizar tareas específicas.
#
# Semántica: el significado o efecto previsto de declaraciones o conjuntos de palabras, tanto en lenguajes humanos como informáticos.
#
# Sintaxis: las reglas sobre cómo se construyen cada declaración en lenguajes humanos e informáticos.
#
# Variables: se utilizan para almacenar temporalmente valores modificables en el código de programación.

# %%
print(7+8)
# Out:
# 15

# %%
print("hello "+ "world")

# %%
print(7+"8")
#this will throw an error

# %%
print(type("a"))
print(type(2))
print(type(2.5))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
print(7+8.5)
print("a"+"b"+"c")
print("This " + "is " + "pretty " + "neat!")
base = 6
height = 3
area = (base*height)/2
print("The area of the triangle is: " + str(area))

# %% [markdown]
# Un ejemplo de como utilizar las variables y la conversión a otro tipo de datos;

# %%
total = 2048 + 4357 + 97658 + 125 + 8
files = 5
average = total / files
print("The average size is:" + str(average))
# Out:
# The average size is:20839.2

# %% [markdown]
# Guía de estudio: Expresiones y variables.
# Información:Este elemento incluye contenido que aún no se tradujo a tu idioma preferido.
# Esta guía de estudio proporciona un resumen de referencia rápida de lo que aprendió en esta lección y sirve como guía para la próxima prueba de práctica.
#
# En el segmento Expresiones y variables, aprendió sobre expresiones, variables y tipos de datos: cadena, entero y flotante. Aprendió a convertir un valor de un tipo de datos a otro y a resolver algunos errores comunes en Python.
#
#
# Términos
# expresión : una combinación de números, símbolos u otros valores que producen un resultado cuando se evalúan
#
# tipos de datos : clases de datos (p. ej., cadena, int, flotante, booleano, etc.), que incluyen las propiedades y comportamientos de instancias del tipo de datos (variables).
#
# variable : una instancia de una clase de tipo de datos, representada por un nombre único dentro del código, que almacena valores modificables del tipo de datos específico
#
# Conversión implícita : cuando el intérprete de Python convierte automáticamente un tipo de datos en otro.
#
# conversión explícita : cuando se escribe código para convertir manualmente un tipo de datos a otro mediante una función de conversión de tipos de datos:
#
# str() : convierte un valor (a menudo numérico) en un tipo de datos de cadena
#
# int() - convierte un valor (normalmente un flotante) a un tipo de datos entero
#
# float() : convierte un valor (normalmente un número entero) en un tipo de datos flotante
#
#
# Variables anotadas por tipo
# Las anotaciones de tipo son opcionales en Python. Sin embargo, pueden resultar muy útiles porque facilitan la lectura del código. Las anotaciones aclaran los tipos de variables para quienes leen el código. También pueden ayudarle a detectar errores durante la compilación. En el siguiente ejemplo, utilizamos el módulo de escritura para anotar los diferentes tipos de variables.

# %%
import typing
# Define a variable of type str
z: str = "Hello, world!"
# Define a variable of type int
x: int = 10
# Define a variable of type float
y: float = 1.23
# Define a variable of type list
list_of_numbers: typing.List[int] = [1, 2, 3]
# Define a variable of type tuple
tuple_of_numbers: typing.Tuple[int, int, int] = (1, 2, 3)
# Define a variable of type dict
dictionary: typing.Dict[str, int] = {"key1": 1, "key2": 2}
# Define a variable of type set
set_of_numbers: typing.Set[int] = {1, 2, 3}

# %% [markdown]
# Habilidades de codificación
#
# Grupo de habilidades 1
# Usar variables para almacenar valores.
#
# Utilice operadores aritméticos básicos con variables para crear expresiones.
#
# Utilice la conversión explícita para cambiar un tipo de datos de flotante a cadena

# %%
# The following lines assign the variable to the left of the =
# assignment operator with the values and arithmetic expressions
# on the right side of the = assignment operator.
hotel_room = 100
tax = hotel_room * 0.08
total = hotel_room + tax
room_guests = 4
share_per_person = total/room_guests


# This line outputs the result of the final calculation stored
# in the variable "share_per_person"
print("Each person needs to pay: " + str(share_per_person)) # change a data type
# Out:
# Each person needs to pay: 27.0

# %% [markdown]
# Grupo de habilidades 2
# Genere múltiples variables de cadena en una sola línea para formar una oración
#
# Utilice el conector más (+) o una coma para conectar cadenas en una función print()
#
# Crear espacios entre variables en una función print()

# %%
# The following 5 lines assign strings to a list of variables.
salutation = "Dr."
first_name = "Prisha"
middle_name = "Jai"
last_name = "Agarwal"
suffix = "Ph.D."

print(salutation + " " + first_name + " " + middle_name + " " + last_name + ", " + suffix)
# The comma as a string ", " adds the conventional use of a comma plus a
# space to separate the last name from the suffix.

# Alternatively, you could use commas in place of the + connector:
print(salutation, first_name, middle_name, last_name,",", suffix)
# However, you will find that this produces a space before a comma within a string.

# %% [markdown]
# Grupo de habilidades 3
# Resolver TypeError causado por un problema de discrepancia en el tipo de datos
#
# Utilice una función de conversión explícita

# %%
# The following code causes a type error between a string
# and an integer:

print("5 * 3 = " + (5*3))


# Resolution:
# print("5 * 3 = " + str(5*3))
#
# To avoid a type error between the string and the integer within the
# print() function, you can make an explicit data type conversion by
# using the str() function to convert the integer to a string.

# %% [markdown]
# Grupo de habilidades 4
# Resolver un ZeroDivisionError causado por un intento de dividir por 0

# %%
numerator = 7
denominator = 0

if denominator == 0:
    print(numerator)
else:
    result = numerator / denominator
    print(result)


# One possible assumption for a number divided by zero error might
# include the issue of a null value as a denominator (could happen when
# using a loop to iterate over values in a database). In such cases, the
# desired outcome may be to leave the numerator value intact. The
# numerator value can be preserved by reassigning the denominator with
# the integer value of 1. The result would then equal the numerator.

# %%
def greeting(name):
    print("Welcome, " + name)

greeting("Kay")
greeting("Cameron")

def greeting(name, department):
    print("Welcome, " + name)
    print("You are part of " + department)

greeting("Blake", "Software engineering")
greeting("Ellis", "Software engineering")
# Out:
# Welcome, Kay
# Welcome, Cameron
# Welcome, Blake
# You are part of Software engineering
# Welcome, Ellis
# You are part of Software engineering

# %% [markdown]
# Funciones integradas
# Información:Este elemento incluye contenido que aún no se tradujo a tu idioma preferido.
# Funciones integradas
# En el último video, exploramos las funciones integradas en Python, incluidas print() , type() y str() . Las funciones integradas son funciones que existen dentro de Python y se pueden llamar directamente. En esta lectura, los explorará más a fondo y también aprenderá sobre la función sorted() y las funciones max() y min() . Además, revisará cómo pasar el resultado de una función a otra función.
#
#
# imprimir()
# La función print() muestra un objeto específico en la pantalla. La función print() es una de las funciones más utilizadas en Python porque le permite generar cualquier detalle de su código.
#
# Para usar la función print() , pasa el objeto que desea imprimir como argumento de la función. La función print() toma cualquier número de argumentos, separados por una coma, y ​​los imprime todos. Por ejemplo, puede ejecutar el siguiente código que imprime una cadena, una variable, otra cadena y un número entero juntos:

# %%
month = "September"
print("Investigate failed login attempts during", month, "if more than", 100)

# %% [markdown]
# tipo()
# La función type() devuelve el tipo de datos de su argumento. La función type() le ayuda a realizar un seguimiento de los tipos de datos de las variables para evitar errores en todo el código.
#
# Para usarlo, pasa el objeto como argumento y devuelve su tipo de datos. Sólo acepta un argumento. Por ejemplo, podría especificar tipo("seguridad") o tipo(7) .
#
# Pasar una función a otra
# Cuando trabaja con funciones, a menudo necesita pasarlas a través de print() si desea mostrar el tipo de datos en la pantalla. Este es el caso cuando se utiliza una función como type(). Considere el siguiente código:

# %%
print(type("This is a string"))

# %% [markdown]
# Muestra str() , lo que significa que el argumento pasado a la función type() es una cadena. Esto sucede porque la función type() se procesa primero y su salida se pasa como argumento a la función print() .
#
#
# cadena()
# La función str() se puede utilizar para convertir cualquier tipo de datos en una cadena. La función str() toma un único argumento, que es el valor que desea convertir en una cadena. La función str() devolverá una representación de cadena del valor.
#
# En este ejemplo, la función str() convertirá el número 12 en una cadena. Esto ejecutará el código e imprimirá la representación de cadena del número.

# %%
number = 12
string_representation = str(number)
print(string_representation)

# %% [markdown]
# ordenado()
# La función sorted() ordena los componentes de una lista. La función sorted() también funciona en cualquier iterable, como una cadena, y devuelve los elementos ordenados en una lista. De forma predeterminada, los ordena en orden ascendente. Cuando se le proporciona un iterable que contiene números, los ordena del más pequeño al más grande; esto incluye iterables que contienen datos numéricos, así como iterables que contienen datos de cadena que comienzan con números. Un iterable que contiene cadenas que comienzan con caracteres alfabéticos se ordenará alfabéticamente.
#
# La función sorted() toma un iterable, como una lista o una cadena, como entrada. Entonces, por ejemplo, puede usar el siguiente código para ordenar la lista de sesiones de inicio de sesión del más corto al más largo:

# %%
time_list = [12, 2, 32, 19, 57, 22, 14]
print(sorted(time_list))

# %% [markdown]
# Esto muestra la lista ordenada.
#
# La función sorted() no cambia el iterable que ordena. El siguiente código ilustra esto:

# %%
time_list = [12, 2, 32, 19, 57, 22, 14]
print(sorted(time_list))
print(time_list)

# %% [markdown]
# La primera función print() muestra la lista ordenada. Sin embargo, la segunda función print() , que no incluye la función sorted() , muestra la lista asignada a time_list en la primera línea de código.
#
# Un detalle más importante sobre la función sorted() es que no puede aceptar listas o cadenas que tengan elementos de más de un tipo de datos. Por ejemplo, no puedes usar la lista [1, 2, "hello"] .
#
#
# máx() y mín()
# La función max() devuelve la entrada numérica más grande que se le pasa. La función min() devuelve la entrada numérica más pequeña que se le pasa.
#
# Las funciones max() y min() aceptan argumentos de múltiples valores numéricos o de un iterable como una lista, y devuelven el valor más grande o más pequeño respectivamente.
#
# Por ejemplo, podría utilizar estas funciones para identificar la sesión más larga o más corta en la que inició sesión un usuario. Si un usuario específico inició sesión siete veces durante una semana y almacenó sus tiempos de acceso en minutos en una lista, puede usar las funciones max() y min() para buscar e imprimir sus sesiones más largas y más cortas:

# %%
time_list = [12, 2, 32, 19, 57, 22, 14]
print(min(time_list))
print(max(time_list))

# %% [markdown]
# Conclusiones clave
# Las funciones integradas son herramientas poderosas en Python que le permiten realizar tareas con un simple comando. La función print() imprime sus argumentos en la pantalla, la función type() devuelve el tipo de datos de su argumento, sorted() organiza su argumento y las funciones min() y max() devuelven los valores más pequeños y más grandes de un iterable respectivamente.
#
# Recursos para más información
# Estas fueron sólo algunas de las funciones integradas de Python. Puedes seguir aprendiendo sobre los demás por tu cuenta:
#
# La documentación de la biblioteca estándar de PythonSe abre en una nueva pestaña
# : una lista de las funciones integradas de Python e información sobre cómo usarlas

# %%
def area_triangle(base, height):
    return base*height/2
area_a = area_triangle(5,4)
area_b = area_triangle(7,3)
sum = area_a + area_b
print("The sum of both areas is: " + str(sum))
# Out:
# The sum of both areas is: 20.5

# %%
def convert_seconds(seconds):
    hours = seconds // 3600
    minutes = (seconds - hours * 3600) // 60
    remaining_seconds = seconds - hours * 3600 - minutes * 60
    return hours, minutes, remaining_seconds

hours, minutes, seconds = convert_seconds(5000)
print(hours, minutes, seconds)
# Out:
# 1 23 20

# %%
name = "Kay"
number = len(name) * 9

print("Hello " + name + ". Your lucky number is " + str(number))

name = "Cameron"
number = len(name) * 9

print("Hello " + name + ". Your lucky number is " + str(number))
# Out:
# Hello Kay. Your lucky number is 27
# Hello Cameron. Your lucky number is 63

# %%
def lucky_number(name):
    number = len(name) * 9
    print("Hello " + name + ". Your lucky number is " + str(number))

lucky_number("Kay")
lucky_number("Cameron")
# Out:
# Hello Kay. Your lucky number is 27
# Hello Cameron. Your lucky number is 63

# %%
def calculate(d):
    q = 3.14
    z = q * (d ** 2)
    print(z)

calculate(5)
#Output is 78.5

# %% [markdown]
# La idea con el codigo anterior es poder definir una funcion, con el fin de reutilizar codigo al maximo posible.
# def calculate(d):
#     q = 3.14
#     z = q * (d ** 2)
#     print(z)
#
# calculate(5)
#
# ```
# # Esto tiene formato de código
# ```
#
#
# #Output is 78.5

# %%
def circle_area(radius):
    pi = 3.14
    area = pi * (radius ** 2)
    print(area)

circle_area(5)
#Output is 78.5
# Out:
# 78.5

# %% [markdown]
# Buenos tarde,
#
# Por favor de su ayuda (operación) agregando el email correspondiente, es importante que las personas que no tienen email de DHL, se asocie el email del líder o jefe directo.
#
#
#
#
# Agradezco se comparta lo más pronto posible esta información.
#
# Gracias, quedo atento!

# %%
# This function calculates the number of days in a variable number of
# years, months, and days. These variables are provided by the user and
# are passed to the function through the function’s parameters.
def find_total_days(years, months, days):
# Assign a variable to hold the calculations for the number of days in
# a year (years*365) plus the number of days in a month (months*30) plus
# the number of days provided through the "days" parameter variable.
    my_days = (years*365) + (months*30) + days
# Use the "return" keyword to send the result of the "my_days"
# calculation to the function call.
    return my_days

# Function call with user provided parameter values.
print(find_total_days(2,5,23))

# %% [markdown]
# Grupo de habilidades 2
#
# Utilice una función para devolver el resultado de una conversión de medidas
#
# Utilice operadores aritméticos para realizar un cálculo.
#
# Combine texto con una llamada de función dentro de una declaración print()
#
# Convierte el valor de retorno de un tipo de datos flotante a una cadena para la función print()
#
# Llame a la función y realice un cálculo sobre el valor de retorno dentro de una declaración print()

# %%
# This function converts fluid ounces to milliliters and returns the
# result of the conversion.
def convert_volume(fluid_ounce):
# Calculate value of the "ml" variable using the parameter variable
# "fluid_ounce". There are approximately 29.5 milliliters in 1 fluid
# ounce.
    ml = fluid_ounce * 29.5
# Return the result of the calculation.
    return ml

# Call the conversion from within the print() function using 2 fluid
# ounces. Convert the return value from a float to a string.
print("The volume in milliliters is " + str(convert_volume(5)))

# Call the function again and double the 2 fluid ounces from within
# the print function.
print("The volume in milliliters is " + str(convert_volume(2)*2))
# Alternative calculation:
# print("The volume in milliliters is " + str(convert_volume(4))
# Out:
# The volume in milliliters is 147.5
# The volume in milliliters is 118.0

# %%
# 1) Complete the code to return the result of the conversion
def convert_distance(km):
	m = km * 1000  # exactly 1000 meters in 1 kilometer
	return m


# Do not indent any of the following lines of code as they are
# meant to be located outside of the function above


my_trip_kilometers = 55


# 2) Convert my_trip_kilometers to meters by calling the function above
my_trip_meters = convert_distance(my_trip_kilometers)


# 3) Fill in the blank to print the result of converting my_trip_kilometers
print("The distance in meters is " + str(my_trip_meters))
# Out:
# The distance in meters is 55000

# %%
def print_seconds(hours, minutes, seconds):
   print(hours*3600+minutes*60+seconds)

print_seconds(1,2,3)
#output will print to the screen
# Out:
# 3723

# %% [markdown]
# **Los siguientes codigos son ejemplos de codigos condicionales**

# %%
print(10>1)
#True
print("cat" == "dog")
#False
print (1 != 2)
#True
# Out:
# True
# False
# True

# %%
print(1 < "1")
#Will return a type error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-bc4656320e3e> in <cell line: 1>()
# ----> 1 print(1 < "1")
#       2 #Will return a type error
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
print(1 == "1")
#False
# Out:
# False

# %%
print("Yellow" > "Cyan" and "Brown" > "Magenta")
#False
# Out:
# False

# %%
print(25 > 50 or 1 != 2)
#True
# Out:
# True

# %%
print(not 42 == "Answer")
#True
# Out:
# True

# %% [markdown]
# **Operadores de comparación con ecuaciones**
# Información:Este elemento incluye contenido que aún no se tradujo a tu idioma preferido.
# Los siguientes ejemplos demuestran cómo utilizar operadores de comparación con los tipos de datos int (enteros, números naturales) y float (número con un punto decimal o valor fraccionario). Los operadores de comparación devuelven resultados booleanos. Como aprendiste anteriormente, Boolean es un tipo de datos que puede contener solo uno de dos valores: True o False .
#
# Los operadores de comparación incluyen:
#
# ==     (igualdad)
#
# !=      (no es igual a)
#
# >        (mayor que)
#
# <       (menos que)
#
# >=     (mayor o igual a)
#
# <=    (menor o igual a)
#
#
# PARTE 1: Operadores de igualdad == y no igual a !=
# En Python, puedes usar operadores de comparación para comparar valores. Cuando se realiza una comparación, Python devuelve un resultado booleano: True o False . Ten en cuenta que los tipos de datos booleanos no son tipos de datos de cadena (el booleano True no es igual a la cadena "True").
#
# Para comprobar si dos valores son iguales, utilice el operador de igualdad : ==
#
# Para comprobar si dos valores no son iguales, utilice el operador distinto de : !=
#
# La función print() se puede utilizar para mostrar los resultados de las comparaciones.
#
# Ejemplos:

# %%
print(32 == 30+2)   # The == operator checks if the 2 values are
True                # equal to each other. If they are equal,
                    # Python returns a True result.


print(5+10 == 6+7)  # If the two values are not equal, as in the
False               # expression 5+10 == 6+7 (or 15 == 13), Python
                    # returns a False result.


print(10-4 != 10+4) # The != operator checks if the 2 values are
True                # NOT equal to each other. If true, Python
                    # returns a True result.


print(9/3 != 3*1)   # In this last example, 9/3 != 3*1 (or 3 != 3)
False               # is false. So, Python returns a False value.
# Out:
# True
# False
# True
# False
# False

# %% [markdown]
# El operador de igualdad == versus el operador  igual =
# Es importante tener en cuenta que el operador de comparación igualdad == realiza una tarea diferente a la del operador de asignación igual = . El operador igual = asigna el valor en el lado derecho del operador igual = al objeto (por ejemplo, una variable) en el lado izquierdo del operador igual = .
#
# Ejemplos:

# %%
# The = equals assignment operator is used to assign a value to a
# variable.

my_variable = 3*5           # Assigns a value to my_variable
print(my_variable)          # Printing the variable returns the
15                          # value assigned to the variable.



# The == equality comparison operator checks if the values of the two
# expressions on either side of the == operator are equivalent to one
# another.

print(my_variable == 3*5)   # Printing the variable returns a Boolean
                        # True or False result.
# Out:
# 15
# True

# %% [markdown]
# PARTE 2: Operadores mayor que > y menor que <
# Los operadores de comparación mayor que > y menor que < también devuelven un resultado booleano Verdadero o Falso después de comparar dos valores.
#
# Para comprobar si un valor es mayor que otro valor, utilice el operador mayor que: >
#
# Para comprobar si un valor es menor que otro valor, utilice el operador menor que: <
#
# Ejemplos:

# %%
print(11 > 3*3)         # The > operator checks if the left value is
True                    # greater than the right value. If true, it
                        # returns a True result.


print(4/2 > 8-4)        # If the > operator finds that the left value
False                   # is NOT greater than the right value, the
                        # comparison will return a False result.


print(4/2 < 8-4)        # The < operator checks  if the left value is
True                    # less than the right side. If true, the
                        # comparison returns a True result.


print(11 < 3*3)         # If the < operator finds that the left side is False
                        # NOT less than the right value, Python returns
False                   # a False result.
# Out:
# True
# False
# True
# False
# False

# %% [markdown]
# PARTE 3: Operadores mayor o igual a >= y menor o igual a <=
# Al igual que los otros operadores de comparación, los operadores mayor o igual a >= y menor o igual a <= devuelven un resultado booleano Verdadero o Falso cuando se realiza una comparación.
#
# Para comprobar si un valor es mayor o igual a otro valor, utilice el operador mayor o igual a: >=
#
# Para comprobar si un valor es menor o igual a otro valor, utilice el operador menor o igual a: <=
#
# Ejemplos:

# %%
print(12*2 >= 24)   # The >= operator checks if the left value is
True                # greater than or equal to the right value.
                    # If one of these conditions is true,
                    # Python returns a True result. In this case
                    # the two values are equal. So, the comparison
                    # returns a True result.


print(18/2 >= 15)   # If the >= comparison determines that the left
False               # value is NOT greater than or equal to the
                    # right, it returns a False result.

print(12*2 <= 30)   # The <= operator checks if the left value is
True                # less than or equal to the right value. In
                    # this case, the left value is less than the
                    # right value. Again, if one of the two
                    # conditions is true, Python returns a True
                    # result.


print(15 <= 18/2)   # If the <= comparison determines that the left
False               # value is NOT less than or equal to the right
                    # value, the comparison returns a False result.

# %% [markdown]
# ![2024-06-27_18h32_09.png](data:image/png;base64,...)

# %% [markdown]
# [Order of Operations](https://www.mathsisfun.com/operation-order-pemdas.html)
#
#
# [Python Comparison Operators with Syntax and Example](https://data-flair.training/blogs/python-comparison-operators/)
#
#
# [Raise numbers to a power: here’s how to exponentiate in Python](https://kodify.net/python/math/exponents/)

# %% [markdown]
# **Operadores de comparación con cadenas**
#
#
# Información:Este elemento incluye contenido que aún no se tradujo a tu idioma preferido.
# En esta lectura, aprenderá más sobre lo que los operadores de comparación pueden y no pueden hacer. Si usa los operadores == (igualdad) y != (no igual a) con cadenas, puede verificar si dos cadenas contienen el mismo texto o no. También puede alfabetizar cadenas usando operadores de comparación > (mayor que), < (menor que) , >= (mayor o igual que) , <= (menor o igual que). Al igual que con los tipos de datos numéricos, los operadores de comparación utilizados con cadenas devolverán resultados   booleanos ( Verdadero , Falso ).
#
#
#
# PARTE 1: Operadores de igualdad == y no igual a != con cadenas
# En Python, puedes usar operadores de comparación para comparar cadenas. Los operadores igualdad == y no igual a != son útiles cuando necesita buscar una cadena específica en un cuerpo de texto, un archivo de registro, una hoja de cálculo, una base de datos y más. También puede verificar las cadenas de entrada del usuario para compararlas con otra cadena. Tenga en cuenta que los tipos de datos booleanos no son tipos de datos de cadena (Boolean True no es igual a la cadena "True").
#
# Ejemplos:

# %%
# The == operator can check if two strings are equal to each other.
# If they are equal, the Python interpreter returns a True result.
print("a string" == "a string")
True


# In this example, the equality == comparison is between "4 + 5" and
# 4 + 5. Since the left data type is a string and the right data type
# is an integer, the two values cannot be equal. So, the comparison
# returns a False result.
print("4 + 5" == 4 + 5)
False


# The != operator can check if the two strings are NOT equal to each
# other. If they are indeed not equal, then Python returns a True result.
print("rabbit" != "frog")
True


# In this example, the variable event_city has been assigned the string
# value "Shanghai". This variable is compared to a static string,
# "Shanghai", using the != operator. As, the strings "Shanghai" and
# "Shanghai" are the same, the comparison of "Shanghai" != "Shanghai"
# is false. Accordingly, Python will return a False result.
event_city = "Shanghai"
print(event_city != "Shanghai")
False

# This last example illustrates the result of trying to compare two
# items of different data types using the equality == operator. The
# two items are not equal, so the comparison returns False.
print("three" == 3)
False
# Out:
# True
# False
# True
# False
# False
# False

# %% [markdown]
# PARTE 2: Los operadores mayor que > y menor que <
# Los operadores de comparación mayor que > y menor que < se pueden usar para alfabetizar palabras en Python. Las letras del alfabeto tienen códigos numéricos en Unicode (también conocidos como valores ASCII). Las letras mayúsculas de la A a la Z están representadas por los valores Unicode del 65 al 90. Las letras minúsculas de la A a la Z están representadas por los valores Unicode del 97 al 122.
#
# Imagen que contiene los valores Unicode de cada letra del alfabeto
# Para verificar si las primeras letras de una cadena tienen un valor Unicode mayor (lo que significa que la letra está más cerca de 122 o z minúscula) que la primera letra de otra cadena, use el operador mayor que: >
#
# Para verificar si las primeras letras de una cadena tienen un valor Unicode más pequeño (lo que significa que la letra está más cerca de 65 o A mayúscula) que la primera letra de otra cadena, use el operador menor que: <
#
# Al igual que las comparaciones numéricas con los operadores mayor que > y menor que < , las comparaciones entre cadenas también devuelven resultados booleanos Verdadero o Falso .
#
# Ejemplos:

# %%
# The greater than > operator checks if the left string has a higher
# Unicode value than the right string. If true, the Python interpreter
# returns a True result. Since W has a Unicode value of 87, and you can
# easily calculate that F has a Unicode value of 70, this comparison is
# the same as 87 > 70. As this is true, Python will return a True
# result.
print("Wednesday" > "Friday")
True


# The less than < operator checks if the left string has a lower
# Unicode value than the right string. If you reference the Unicode
# chart above, you can see that all lowercase letters have higher
# Unicode values than uppercase letters. We can see that B has a
# Unicode value of 66 and b has a Unicode value of 98. This
# comparison is the same as 66 < 98, which is true. So, Python will
# return a True result.
print("Brown" < "brown")
True


# If the strings have the same first few letters, the comparison will
# cycle through each letter of each string, from left to right until it
# finds two letters that have different Unicode values. In this example,
# both strings share the initial substring "sun", but then have
# different letters with different Unicode values in the fourth place
# in each string. So, the fourth letters 'b' and 't' of the two
# strings are used for the comparison. Since 'b' does not have a higher
# Unicode value than 't', the comparison returns a False result.
print("sunbathe" > "suntan")
False


# If two identical strings are compared using the less than < comparison
# operator, this will produce a False result because they are equal.
print("Lima" < "Lima")
False


# This last example illustrates the result of trying to compare two
# items of different data types using the less than < operator. The
# greater than > and less than operators < cannot be used to compare
# two different data types.
print("Five" < 6)
'''
Error on line 1:
    print("Five" < 6)
TypeError: '<' not supported between instances of 'str' and 'int'

PARTE 3: Los operadores mayor o igual a >= y menor o igual a <=
Los operadores mayor o igual a >= y menor o igual a <= también se pueden utilizar con cadenas. Al igual que los demás operadores de comparación, devolverán un resultado booleano verdadero o falso cuando se realice una comparación entre dos cadenas.

Para comprobar si una cadena tiene un valor Unicode mayor o igual que la primera letra de otra cadena, utilice el operador mayor o igual que: >=

Para comprobar si una cadena tiene un valor Unicode menor o igual que la primera letra de otra cadena, utilice el operador menor o igual a: <=

En este punto, ya deberías estar familiarizado con el funcionamiento de los operadores de comparación en Python. ¿Puedes determinar cuáles serán los resultados de las comparaciones que se enumeran a continuación? Cuando estés listo para comprobar tus respuestas, haz clic en Ejecutar.

"mi computadora" >= "mi silla"

"Primavera" <= "Invierno"

"piña" >= "piña"

# %%
# Use the Unicode chart in Part 2 to determine if the Unicode values of
# the first letters of each string are higher, lower, or equal to one
# another.


var1 = "my computer" >= "my chair"
var2 = "Spring" <= "Winter"
var3 = "pineapple" >= "pineapple"

print("Is \"my computer\" greater than or equal to \"my chair\"? Result: ", var1)
print("Is \"Spring\" less than or equal to \"Winter\"? Result: ", var2)
print("Is \"pineapple\" less than or equal to \"pineapple\"? Result: ", var3)
# Out:
# Is "my computer" greater than or equal to "my chair"? Result:  True
# Is "Spring" less than or equal to "Winter"? Result:  True
# Is "pineapple" less than or equal to "pineapple"? Result:  True

# %% [markdown]
# Conclusiones clave
# Los operadores de comparación de Python devuelven resultados booleanos ( Verdadero o Falso ) con cadenas:
#
# Expresión
#
# Descripción
#
# "un" == "un"
#
# Si la cadena "a" es idéntica a la cadena "a", devuelve Verdadero. De lo contrario, devuelve Falso.
#
# "a" no es igual a "b"
#
# Si la cadena "a" no es idéntica a la cadena "b"
#
# "a" > "b"
#
# Si la cadena "a" tiene un valor Unicode mayor que la cadena "b"
#
# "a" >= "b"
#
# Si el valor Unicode de la cadena "a" es mayor o igual que el valor Unicode de la cadena "b"
#
# "a" < "b"
#
# Si la cadena "a" tiene un valor Unicode menor que la cadena "b"
#
# "a" <= "b"
#
# Si el valor Unicode de la cadena "a" es menor o igual que el valor Unicode de la cadena "b"

# %%
# Define strings
listOfPlaces = ["Berlin", "Paris", "Lausanne"]
currentCity = "Lausanne"

for place in listOfPlaces:
    print (f"comparing {place} with {currentCity}: %{place == currentCity}")

    # Define the strings
listOfPlaces = ["Berlin", "Paris", "Lausanne"]
currentCity = "Lausanne"

for place in listOfPlaces:
    if place < currentCity:
            print (f"{place} comes before {currentCity}")
    elif place > currentCity:
            print (f"{place} comes after {currentCity}")
    else:
            print (f"{place} is equal to {currentCity}")


            # using the == operator
listOfPlaces = ["Berlin", "Paris", "Lausanne"]
currentCity = "lausANne"

for place in listOfPlaces:
    print (f"comparing {place} with {place.lower() == currentCity.lower()}: {currentCity}")
# Out:
# comparing Berlin with Lausanne: %False
# comparing Paris with Lausanne: %False
# comparing Lausanne with Lausanne: %True
# Berlin comes before Lausanne
# Paris comes after Lausanne
# Lausanne is equal to Lausanne
# comparing Berlin with False: lausANne
# comparing Paris with False: lausANne
# comparing Lausanne with True: lausANne

# %%
# import the additional module
import re

# define list of places
listOfPlaces = ["Bayswater", "Table Bay", "Beijing", "Bombay"]

# define search string
pattern = re.compile("[Bb]ay")

for place in listOfPlaces:
    if pattern.search(place):
        print (f"{place} matches the search pattern")
# Out:
# Bayswater matches the search pattern
# Table Bay matches the search pattern
# Bombay matches the search pattern

# %%
# Import the additional module
import difflib

# Define original text,
# taken from: https://en.wikipedia.org/wiki/Internet_Information_Services
original = ["About the IIS", "", "IIS 8.5 has several improvements related", "to performance in large-scale scenarios, such", "as those used by commercial hosting providers and Microsoft's", "own cloud offerings."]

# Define modified text
edited = ["About the IIS", "", "It has several improvements related", "to performance in large-scale scenarios."]

# Initiate the Differ object
d = difflib.Differ()

# Calculate the difference between the two texts
diff = d.compare(original, edited)

# Output the result
print ('\n'.join(diff))
# Out:
#   About the IIS
#
# - IIS 8.5 has several improvements related
# ?  ^^^^^^
#
# + It has several improvements related
# ?  ^
#
# - to performance in large-scale scenarios, such
# ?                                        ^^^^^^
#
# + to performance in large-scale scenarios.
# ?                                        ^
#
# - as those used by commercial hosting providers and Microsoft's
# - own cloud offerings.

# %% [markdown]
# **Operadores logicos**
# Información:Este elemento incluye contenido que aún no se tradujo a tu idioma preferido.
# Los operadores lógicos se utilizan para construir expresiones más complejas. Puedes hacer comparaciones complejas uniendo enunciados de comparación mediante los operadores lógicos: and , or , not . Las comparaciones complejas devuelven un resultado  booleano ( Verdadero o Falso ).
#
# y
#
# Ambos lados de la declaración que se evalúa deben ser verdaderos para que toda la declaración sea verdadera.
#
# Ejemplo: (5 > 1 y 5 < 10) = Verdadero
#
# o
#
# Si cualquiera de los lados de la comparación es verdadero, entonces toda la afirmación es verdadera.
#
# Ejemplo: (color = "azul" o color = "verde") = Verdadero
#
# no
#
# Invierte el resultado booleano de la instrucción que le sigue inmediatamente. Por lo tanto, si una instrucción se evalúa como verdadera y ponemos el operador not delante de ella, se convertirá en falsa.
#
# Ejemplo: ( no "A" == "A") = Falso
#
#
# PARTE 1: El operador lógico y
# En Python, puedes usar el operador lógico y para conectar más de una comparación. Este tipo de comparación compleja se usa para verificar si dos declaraciones de comparación son verdaderas o no. Puedes usar el operador y cuando necesites ejecutar un bloque de código, pero solo si dos condiciones diferentes son verdaderas. Por ejemplo, es posible que quieras escribir un script que automatice el envío de una alerta de emergencia si un servidor deja de responder y hay un aumento inusual en la cantidad de empleados que abren tickets de problemas.
#
# Ejemplo 1:
#
# El siguiente modelo demuestra el uso del operador lógico and para unir comparaciones entre dos expresiones matemáticas. La descripción que aparece debajo del ejemplo explica el orden en el que Python procesará la línea de código.

# %%
# Example 1

print((6*3 >= 18) and (9+9 <= 36/2))
# Out:
# True

# %% [markdown]
# En el ejemplo anterior, Python completó las siguientes actividades en el siguiente orden:
#
# Python resuelve las expresiones numéricas utilizando el orden de operaciones. (6*3 >= 18) y (9+9 <= 36/2) se convierte en (18 >= 18) y (18 <= 18)
#
# Python compara los resultados de las expresiones numéricas utilizando los operadores de comparación (en este caso >= y <=). (18 >= 18) y (18 <= 18) se convierten en True y True
#
# Python comprueba si ambos lados del operador lógico "y" son verdaderos. True y True se convierten en True
#
# Python devuelve un valor booleano: verdadero o falso. La comparación compleja devuelve un resultado verdadero.
#
#
# Ejemplo 2:
#
# En el siguiente ejemplo, "Nairobi" < "Milán" y "Nairobi" > "Hanói", el operador lógico y conecta dos declaraciones de comparación de cadenas. Aprendió anteriormente que el uso de los operadores mayor que y menor que en cadenas probará el orden alfabético (técnicamente, valores Unicode) de las cadenas. Por lo tanto, esta comparación compleja verifica si "Nairobi" está alfabetizado antes de "Milán" (Falso) Y después de "Hanói" (Verdadero).
#
# Esta comparación devuelve un resultado Falso porque ambos lados del operador lógico no son Verdaderos. Una declaración de comparación como esta se puede utilizar para iterar a través de una lista de nombres y comprobar si están ordenados alfabéticamente en el orden correcto.

# %%
# Example 2

print("Nairobi" < "Milan" and "Nairobi" > "Hanoi")
# Out:
# False

# %% [markdown]
# PARTE 2: El operador lógico o
# El operador lógico or prueba dos condiciones para determinar si al menos un lado del operador lógico or es Verdadero. El resultado de la prueba se puede utilizar para activar un bloque de código si se cumple al menos una condición.
#
# Sintaxis:
#
# 1
# Expression1 or Expression2
# Devuelve valores booleanos:
#
# Expresión1
#
# Expresión2
#
# Devuelve el resultado
#
# Verdadero
#
# Verdadero
#
# Verdadero
#
# Verdadero
#
# FALSO
#
# Verdadero
#
# FALSO
#
# Verdadero
#
# Verdadero
#
# FALSO
#
# FALSO
#
# FALSO
#
# Ejemplos:

# %%
# Define country and city variables
country = "United States"
city = "New York City"

# True or True returns True
print((15/3 < 2+4) or (0 >= 6-7))  # True or True = True

# False or True returns True
print(country == "New York City" or city == "New York City")  # False or True = True

# True or False returns True
print(16 <= 4**2 or 9**(0.5) != 3)  # True or False = True

# False or False returns False
print("B_name" > "C_name" or "B_name" < "A_name") # False or False = False
# Out:
# True
# True
# True
# False

# %% [markdown]
# **PARTE 3: El operador no lógico**
# El operador no lógico invierte el valor de la expresión de comparación. Esta es una herramienta útil cuando se desea ejecutar un bloque de código siempre que no se cumpla una determinada condición.
#
# Si la expresión condicional es Verdadera, se puede agregar el operador no lógico para hacer que la expresión no sea Verdadera (Falso).
#
# Si la expresión condicional es Falsa, se puede agregar el operador no lógico para hacer que la expresión no sea Falsa (Verdadero).
#
# Sintaxis:
#
# 1 not expression

# %%
# Test Example 1:

x = 2*3 > 6
print("The value of x is:")
print(x)

print("")  # Prints a blank line

print("The inverse value of x is:")
print(not x)

# %%
# What happens when you negate a False statement?
# Click Run when you are ready to check your answer.


today = "Monday"
print(not today == "Tuesday")


# The "today" variable states today is Monday. This makes the comparison
# "today == Tuesday" False. The logical operator "not" inverts the False
# result to become True. In other words, this expression asks if it is
# false that today is not Tuesday. More succinctly, "not False" means
# True."
# Out:
# True

# %% [markdown]
# **Conclusiones clave**
# Cuando se utilizan operadores lógicos de Python con operadores de comparación, el intérprete devolverá resultados booleanos ( Verdadero o Falso ):
#
# Expresión
#
# Descripción
#
# a == a y a != b
#
# Verdadero si ambos lados son Verdaderos, de lo contrario Falso.
#
# a > b o a <= c
#
# Verdadero si cualquiera de los lados es Verdadero. Falso si ambos lados son Falso.
#
# no a == b
#
# Verdadero si la afirmación es falsa, falso si la afirmación es verdadera.

# %% [markdown]
# **Revisión: Ramificación con instrucciones if**
# Esta lectura contiene el código utilizado en los videos instructivos de
# Ramificación con sentencias if
#
# Introducción
# Esta lectura complementaria está organizada para coincidir con el contenido del video que sigue. Contiene el mismo código que se muestra en el siguiente video. Estos bloques de código le brindarán la oportunidad de ver cómo se escribe el código, le permitirán practicar su ejecución y pueden usarse como referencia para volver a consultarlos.
#
#  Puede seguir la lectura mientras el instructor analiza el código o revisarlo después de ver el video.

# %%
def hint_username(username):
    if len(username) < 3:
        print("Invalid username. Must be at least 3 characters long")
    else:
        print("Correct username")

# Prueba de la función con diferentes nombres de usuario
#hint_username("Jo") # Este nombre de usuario es demasiado corto
hint_username("John") # Este nombre de usuario es lo suficientemente largo
# Out:
# Correct username

# %% [markdown]
# **Revisión: declaraciones else**
# Esta lectura contiene el código utilizado en los videos instructivos de
# Declaraciones else
#
#
#
# Introducción
# Esta lectura complementaria está organizada para coincidir con el contenido del video que sigue. Contiene el mismo código que se muestra en el siguiente video. Estos bloques de código le brindarán la oportunidad de ver cómo se escribe el código, le permitirán practicar su ejecución y pueden usarse como referencia para volver a consultarlos.
#
#  Puede seguir la lectura mientras el instructor analiza el código o revisarlo después de ver el video.

# %%
def hint_username(username):
    if len(username) < 3:
        print("Invalid username. Must be at least 3 characters long")
    else:
        print("Valid username")
hint_username("Car")
#This code will not have an output.
# Out:
# Valid username

# %% [markdown]
# Acerca de este código
# Este fragmento de código define una función llamada hint_username . La sentencia if len(username) < 3 : comprueba la longitud de la cadena username . Si la longitud de la cadena es inferior a 3 caracteres, se ejecuta el código dentro de la sentencia if . La sentencia print("Nombre de usuario no válido. Debe tener al menos 3 caracteres de longitud") imprime el mensaje "Nombre de usuario no válido. Debe tener al menos 3 caracteres de longitud". La sentencia else : se ejecuta si la longitud de la cadena username no es inferior a 3 caracteres. En este caso, se ejecuta el código dentro de la sentencia else , que es la sentencia print("Nombre de usuario válido") .

# %%
def is_even(number):
    if number % 2 == 0:
        return True
    return False

print(is_even(5))
#This code has no ouput
# Out:
# False

# %% [markdown]
# **Acerca de este código**
# Este fragmento de código define una función llamada is_even . Comprueba si un número es par. if number % 2 == 0 : es la parte del código que comprueba si el número es par. Si el número es impar, devolverá falso. El código no tiene ninguna salida actualmente porque no se le ha proporcionado un número para comprobar.

# %%
def is_positive(number):
  if number > 0:
    return True
  else:
    return False

is_positive(-2)
# Out:
# False

# %% [markdown]
# **Sentencias else y el operador módulo**
# Acabamos de hablar de la sentencia if , que ejecuta el código si una evaluación es verdadera y omite el código si es falsa. Pero, ¿qué pasa si queremos que el código haga algo diferente si la evaluación es falsa? Podemos hacerlo usando la sentencia else . La sentencia else sigue a un bloque if y está compuesta por la palabra clave else seguida de dos puntos. El cuerpo de la sentencia else está sangrado a la derecha y se ejecutará si la sentencia if anterior no se ejecuta.
#
# También hablamos del operador módulo, que se representa con el signo de porcentaje: % . Este operador realiza una división de números enteros, pero solo devuelve el resto de esta operación de división. Si dividimos 5 por 2, el cociente es 2 y el resto es 1. Dos 2 pueden caber en 5, dejando 1 sobrante. Por lo tanto, 5%2 devolvería 1. Dividir 10 por 5 nos daría un cociente de 2 sin resto, ya que 5 puede caber en 10 dos veces sin que quede nada. En este caso, 10%5 devolvería 0, ya que no hay resto.

# %% [markdown]
# **Reseña: declaraciones de elif**
# Esta lectura contiene el código utilizado en los videos instructivos de
# Declaraciones elif
#
#
#
# Introducción
# Esta lectura complementaria está organizada para coincidir con el contenido del video que sigue. Contiene el mismo código que se muestra en el siguiente video. Estos bloques de código le brindarán la oportunidad de ver cómo se escribe el código, le permitirán practicar su ejecución y pueden usarse como referencia para volver a consultarlos.
#
# Puede seguir la lectura mientras el instructor analiza el código o revisarlo después de ver el video.

# %%
def hint_username(username):
    if len(username) < 3:
        print("Invalid username. Must be at least 3 characters long")
    else:
        if len(username) > 15:
            print("Invalid username. Must be at most 15 characters long")
        else:
            print("Valid username")
hint_username("Man")
# Out:
# Valid username

# %% [markdown]
# **Acerca de este código**
# Este fragmento de código define una función llamada hint_username . La sentencia if len(username) < 3 : comprueba la longitud de la cadena username . Si la longitud de la cadena es inferior a 3 caracteres, se ejecuta el código dentro de la sentencia if . La sentencia print("Nombre de usuario no válido. Debe tener al menos 3 caracteres de longitud") imprime el mensaje "Nombre de usuario no válido. Debe tener al menos 3 caracteres de longitud". La sentencia else: se ejecuta si la longitud de la cadena username es superior a 15 caracteres. En este caso, se ejecuta el código dentro de la sentencia else , que es la sentencia print("Nombre de usuario no válido. Debe tener como máximo 15 caracteres de longitud") . Si el nombre de usuario tiene la longitud correcta, entre 3 y 15 caracteres de longitud,   se ejecuta print("Nombre de usuario válido") .

# %%
def hint_username(username):
    if len(username) < 3:
        print("Invalid username. Must be at least 3 characters long")
    elif len(username) > 15:
        print("Invalid username. Must be at most 15 characters long")
    else:
        print("Valid username")

# %% [markdown]
# **Ramificación compleja con instrucciones elif**
# Partiendo de los bloques if y else , que nos permiten ramificar nuestro código en función de la evaluación de una declaración, la declaración elif nos permite incluso más comparaciones para realizar ramificaciones más complejas. Muy similar a las declaraciones if , una declaración elif comienza con la palabra clave elif , seguida de una comparación que se evaluará. A esto le siguen dos puntos y, luego, el bloque de código en la siguiente línea, con sangría a la derecha. Una declaración elif debe seguir a una declaración if y solo se evaluará si la declaración if se evaluó como falsa. ¡Puede incluir múltiples declaraciones elif para crear ramificaciones complejas en su código para hacer todo tipo de cosas poderosas!

# %% [markdown]
# **Guía de estudio: condicionales**
# Información:Este elemento incluye contenido que aún no se tradujo a tu idioma preferido.
# Esta guía de estudio proporciona un resumen de referencia rápida de lo que aprendió en esta lección y sirve como guía para la próxima prueba de práctica.
#
# En el segmento Condicionales, aprendiste sobre los operadores integrados de Python que se usan para comparar valores y los operadores lógicos para hacer comparaciones complejas. También aprendiste a usar operadores en bloques if-elif-else.
#
#
#
# Conocimiento
# Operadores de comparación con valores numéricos
# Las expresiones de comparación devuelven un resultado booleano (Verdadero o Falso).
#
# x == y Si x es igual a y, devuelve Verdadero. De lo contrario, devuelve Falso.
#
# x != y Si x no es igual a y, devuelve Verdadero. De lo contrario, devuelve Falso.
#
# x < y Si x es menor que y, devuelve Verdadero. De lo contrario, devuelve Falso.
#
# x <= y Si x es menor o igual que y, devuelve Verdadero. De lo contrario, devuelve Falso.
#
# x > y Si x es mayor que y, devuelve Verdadero. De lo contrario, devuelve Falso.
#
# x >= y Si x es mayor o igual que y, devuelve Verdadero. De lo contrario, devuelve Falso.
#
# Operadores de comparación con cadenas
# Las expresiones de comparación con cadenas también devuelven un resultado booleano (Verdadero o Falso).
#
# "x" == "y" Si las palabras son iguales, devuelve Verdadero. De lo contrario, devuelve Falso.
#
# "x" != "y" Si las palabras no son iguales, devuelve Verdadero. De lo contrario, devuelve Falso.
#
# Cuando se utilizan con cadenas, las siguientes expresiones de comparación ordenarán las cadenas en orden alfabéti-co.
#
# "x" < "y" Si la cadena "x" tiene un valor Unicode menor que la cadena "y", devuelve Verdadero. De lo contrario, devuelve Falso.
#
# "x" <= "y" Si el valor Unicode de la cadena "x" es menor o igual que el valor Unicode de la cadena "y", devuelve Verdadero. De lo contrario, devuelve Falso.
#
# "x" > "y" Si la cadena "x" tiene un valor Unicode mayor que la cadena "y", devuelve Verdadero. De lo contrario, devuelve Falso.
#
# "x" >= "y" Si el valor Unicode de la cadena "x" es mayor o igual que el valor Unicode de la cadena "y", devuelve True. De lo contrario, devuelve False.
#
# Valores Unicode para el alfabeto
#
# Imagen que contiene el valor Unicode de cada letra del alfabeto
#
# La numeración Unicode del alfabeto comienza en 65 para la letra A mayúscula y llega hasta 90 para la letra Z mayúscula. Luego, los valores del alfabeto en minúscula comienzan en 97 para la a minúscula y llegan hasta 122 para la z minúscula. Usando estos números Unicode, el código de la A mayúscula es menor que los códigos de todas las demás letras, lo que Python interpreta como el comienzo del alfabeto. El código de la z minúscula es mayor que los códigos de todas las demás letras, lo que Python interpreta como el final del alfabeto inglés.
#
# Operadores logicos
# Los operadores lógicos se utilizan para combinar expresiones de comparación y también devuelven resultados booleanos (Verdadero o Falso).
#
# Comparación1 y comparación2
#
# Devuelve un resultado Verdadero si tanto la comparación1 como la comparación2 son verdaderas.
#
# Si no son ambos verdaderos, devuelve Falso.
#
# comparación1 o comparación2
#
# Devuelve un resultado Verdadero si comparison1 y/o comparison2 son Verdaderos.
#
# Si ninguna comparación es verdadera, devuelve Falso.
#
# No comparación1
#
# Devuelve el valor booleano inverso de la comparación.
#
# Devuelve un resultado Verdadero si comparison1 es falso.
#
# Si la comparación1 es verdadera, entonces devuelve Falso.

# %%
if condition1:
    action1
elif condition2:
    action2
else:
    action3

# %% [markdown]
# Si la condición 1 es verdadera:
#
# Luego realice la acción 1 y salga del bloque if-elif-else
#
# Si la condición 2 es verdadera:
#
# Luego realice la acción 2 y salga del bloque if-elif-else
#
# Si ni la condición1 ni la condición2 son verdaderas:
#
# Luego realice la acción 3 y salga del bloque if-elif-else
#
#
# **Habilidades de codificación**
# Grupo de habilidades 1
#
# Utilice un operador de comparación con números
#
# Utilice un operador de comparación para ordenar cadenas alfabéticamente

# %%
# The value of 10*4 (40) is greater than 14+23 (37), therefore this
# comparison expression will return the Boolean value of True.


print(10*4 > 14+23) # Should print True

# The letter "t" has a Unicode value of 116 and the letter "s" has a
# Unicode value of 115. Since 116 is not less than 115, the
# comparison of "tall" < "short" (or 116 < 115) is False.

print("tall" < "short")  # Should print False

# %% [markdown]
# **Grupo de habilidades 2**
#
# Utilice una función con la palabra clave def()
#
# Pasar un parámetro a la función
#
# Utilice una declaración if-elif-else
#
# Asignar cadenas a variables
#
# Utilice operadores condicionales
#
# Devuelve un valor

# %%
# This function accepts one variable as a parameter
def translate_error_code(error_code):

# The if-elif-else block assesses the value of the variable
# passed to the function as a parameter. The if statement uses
# the equality operator == to test the value of the variable.
# This test returns a Boolean (True/False) result.
    if error_code == "401 Unauthorized":
# If the comparison above returns True, then the indented
# line(s) inside the if-statement will run. In this case, the
# action is to assign a string to the translation variable.
# The remainder of the if-elif-else block will not run.
# The Python interpreter will skip to the next line outside of
# the if-elif-else block. In this case, the next line is the
# return value statement.
        translation = "Server received an unauthenticated request"

# If the initial if-statement returns a False result, then the
# first elif-statement will run a different test on the value
# of the variable.
    elif error_code == "404 Not Found":
# If the first elif-statement returns a True result, then the
# indented line(s) inside the first elif-statement will run.
# After this line, the remainder of the if-elif-else block will
# not run. The Python interpreter will skip to the next line
# outside of the if-elif-else block.
        translation = "Requested web page not found on server"

# If both the initial if-statement and the first elif-statement
# return a False result, then the second elif-statement will
# run.
    elif error_code == "408 Request Timeout":
# If the second elif-statement returns a True result, then the
# indented line(s) inside the second elif-statement will run.
# After this line, the remainder of the if-elif-else block will
# not run. The Python interpreter will skip to the next line
# outside of the if-elif-else block.
        translation = "Server request to close unused connection"

# If the conditional tests above do not produce a True result
# then the else-statement will run.
    else:
        translation = "Unknown error code"
# The if-elif-else block ends.

# The next line outside of the if-elif-else block will run
# after exiting the block. In this case, the next line returns
# the output from the if-elif-else block.
    return translation

# The print() function allows us to display the output of the
# function. To call a function in a print statement, the syntax
# is print(name_of_function(parameter))
print(translate_error_code("404 Not Found"))

# Expected output:
# Requested web page not found on server

# %% [markdown]
# **Grupo de habilidades 3**
#
# Utilice una declaración if-elif-else con:
#
# operadores de comparación
#
# operadores logicos

# %%
# Sets value of the "number" variable
number = 25

# The "number" variable will first be compared to 5. Since it is
# False that "number" is not less than or equal to 5, the expression indented
# under this line will be ignored.
if number <= 5:
   print("The number is 5 or smaller.")

# Next, the "number" variable will be compared to 33. Since it is
# False that "number" is equal to 33, the expression indented under
# this line will be ignored.
elif number == 33:
   print("The number is 33.")

# Then, the "number" variable will be compared to 32 and 6. Since it
# is True that 25 is less than 32 and greater than 6, the Python
# interpreter will print "The number is less than 32 and/or greater
# than 6." Then, it will exit the if-elif-else statement and the remainder
# of the if-elif-else statement will be ignored.
elif number < 32 and number >= 6:
   print("The number is less than 32 and greater than 6.")

else:
   print("The number is " + str(number))

# Expected output is:
# The number is less than 32 and greater than 6.

# %%
# This function rounds a variable number up to the nearest 10x value
def round_up(number):
  x = 10
# The floor division operator will calculate the integer value of
# "number" divided by x: 35 // 10 will return the integer 3.
  whole_number = number // x
# The modulo operator will calculate the remainder value of "number"
# divided by x: 35 % 10 will return the remainder value 5.
  remainder = number % x
# If the remainder is greater than or equal to 5:
  if remainder >= 5:
# Return x multiplied by the (whole_number+1) to round up
    return x*(whole_number+1)
# Else, return x multiplied by the whole_number to round down
  return x*whole_number

# Calls the function with the parameter value of 35.
print(round_up(35)) # Should print 40
# Out:
# 40

# %% [markdown]
# **Términos y definiciones del Curso 1, Módulo 2**
# Funciones integradas: funciones que existen dentro de Python y se pueden llamar directamente
#
# Comentarios: Notas para usted y/o otros programadores para aclarar el propósito del código.
#
# Tipos de datos: clases de datos (por ejemplo, cadena, int, float, booleano, etc.), que incluyen las propiedades y comportamientos de instancias del tipo de datos (variables)
#
# Conversión explícita: esto ocurre cuando se escribe código para convertir manualmente un tipo de datos a otro utilizando una función de conversión de tipo de datos.
#
# Expresión: Una combinación de números, símbolos u otros valores que producen un resultado cuando se evalúan.
#
# Conversión implícita: esto ocurre cuando el intérprete de Python convierte automáticamente un tipo de datos a otro.
#
# Operadores lógicos: Operadores utilizados para combinar o manipular valores booleanos (Verdadero o Falso) para crear condiciones complejas para la toma de decisiones.
#
# Parámetro (argumento): un valor que se pasa a una función para su uso dentro de la función y que controla el comportamiento del lector y escritor de CSV.
#
# Refactorización: cuando se actualiza un código para que sea más autodocumentado y aclare la intención.
#
# Valor de retorno : este es el valor o variable devuelto como resultado final de una función

# %% [markdown]
# **Guía de estudio: Módulo 2: Cuestionario calificado**
# Información:Este elemento incluye contenido que aún no se tradujo a tu idioma preferido.
# Es hora de prepararse para el cuestionario calificado del Módulo 2. Revise los siguientes elementos de este Módulo antes de comenzar el cuestionario calificado del Módulo 2. Si desea refrescar su memoria sobre estos materiales, vuelva a consultar las Guías de estudio que se encuentran antes de cada cuestionario de práctica del Módulo 2:
# Guía de estudio: Expresiones y variables
# ,
# Guía de estudio: Funciones
# , y
# Guía de estudio: condicionales
# .
#
# Conocimiento
# Cómo asignar valores a variables y utilizarlos en código
#
# Cómo construir una función y utilizar parámetros de función
#
# Cómo se pueden utilizar los operadores lógicos y de comparación
#
# Cómo se comportan los operadores lógicos y de comparación con diferentes tipos de datos
#
# ¿Qué tipo de resultados producen las comparaciones simples y complejas?
#
# Cómo ordenar cadenas alfabéticamente mediante operadores de comparación
#
# ¿Qué debe aparecer después de las palabras clave if y elif?
#
# ¿Qué hace  la palabra clave elif ?
#
# Cuándo se ejecutará una instrucción if, elif o else
#
# Cómo utilizar los operadores de división de piso // y módulo % y por qué
#
# Cómo utilizar operadores lógicos con operadores de comparación para desarrollar sentencias condicionales complejas dentro de un bloque if-elif-else
#
# Mejores prácticas para la codificación y sus beneficios
#
# Qué significa “código autodocumentado”
#
#
# Es posible que el cuestionario contenga algunas preguntas sobre el resultado de un pequeño bloque de código o el valor de una parte del código. Asegúrese de leer atentamente las instrucciones de esas preguntas.
#
# Habilidades de codificación
# Grupo de habilidades 1
# Utilice una función con la palabra clave def()
#
# Pasar un parámetro a la función
#
# Utilice un bloque if-elif-else para establecer condiciones específicas para una variedad de acciones
#
# Asignar cadenas a variables
#
# Utilice operadores de comparación
#
# Devuelve un valor
#
# Llamar a la función en una declaración de impresión y pasar el parámetro a la función

# %%
# A function is created with the def() keyword. The parameter
# variable "time_as_string" is passed to the function through a
# call to the function.
def task_reminder(time_as_string):

    # The following if-elif-else block assigns various strings to
    # the variable "task" depending on specific conditions. The
    # test conditions are set using the == equality comparison
    # operator. In this case, the time passed through the
    # "time_as_string" parameter variable is tested as the
    # specific condition. So, if the time  is "11:30 a.m.", then
    # "task" is assigned the value: "Run TPS report".
    if time_as_string == "8:00 a.m.":
        task = "Check overnight backup images"
    elif time_as_string == "11:30 a.m.":
        task = "Run TPS report"
    elif time_as_string == "5:30 p.m.":
        task = "Reboot servers"
    # The else statement is a catchall for all other values of
    # the "time_as_string" parameter variable not listed in the
    # if-elif block of code.
    else:
        task = "Provide IT Support to employees"

    # This line returns the value of "task" to the function call.
    return task

# This line calls the function and passes a parameter
# ("10:00 a.m.") to the function.
print(task_reminder("10:00 a.m."))
# Should print "Provide IT Support to employees"

# %% [markdown]
# **Grupo de habilidades 2**
# Predecir la salida de expresiones escritas con la sintaxis de Python.
#
# Requiere comprensión de:
#
# Operadores aritméticos y lógicos
#
# Cómo las funciones devuelven e imprimen valores
#
# Cómo funcionan las sentencias if-elif-else
#
# Operadores de comparación

# %%
# Example 1
# Evaluate the output of this print statement

def product(a, b):
        return(a*b)

print(product(product(2,4), product(3,5)))

#################################

# Example 2
# Evaluate the output of this print statement

def difference(a, b):
        return(a-b)

def sum(a, b):
        return(a+b)

print(difference(sum(2,2), sum(3,3)))


#################################


# Example 3
# Evaluate the Boolean output of this comparison


print((5 >= 2*4) and (5 <= 4*3))


#################################


# Example 4
# Evaluate the value of the comparison in the if statement


x = 3
if x+5 > x**2 or x % 4 != 0:
        print("This comparison is True")


#################################


# Example 5
# Evaluate the output of this if-elif-else statement


number = 6
if number * 2 < 14:
        print(number * 6 % 3)
elif number > 7:
        print(100 / number)
else:
        print(7 - number)


# Click Run to check your answers. If you are having trouble
# calculating the correct answers manually, please review the
# Practice Quiz Study Guides, videos, and readings in this Module.

# %% [markdown]
# **Skill Group 3**
# Create an if-elif-else statement with:
#
# a complex conditional statement using both comparison and logical operators
#
# values assigned to variables
#
# arithmetic operators, including the modulo % operator

# %%
def get_remainder(x, y):

  if x == 0 or y == 0 or x ==y:
    remainder = 0
  else:
    remainder = (x % y) / y
  return remainder


print(get_remainder(10, 3))

# %% [markdown]
# Recordatorio: la sintaxis correcta es fundamental
# El uso de una sintaxis precisa es fundamental al escribir código en cualquier lenguaje de programación, incluido Python. Incluso un pequeño error tipográfico puede provocar un error de sintaxis y el calificador automático de cuestionarios codificados en Python marcará su código como incorrecto. Esto refleja los errores de codificación de la vida real en el sentido de que un solo error de ortografía, mayúsculas y minúsculas, puntuación, etc. puede hacer que su código falle. Los problemas de codificación causados ​​por una sintaxis imprecisa siempre serán un problema, ya sea que esté aprendiendo un lenguaje de programación o esté utilizando habilidades de programación en el trabajo. Por lo tanto, es fundamental comenzar a adquirir el hábito de ser preciso en su código ahora.
#
# No se otorgará ningún crédito si hay algún error de codificación en los cuestionarios calificados automáticamente, incluidos errores menores. Afortunadamente, tienes 3 oportunidades opcionales de volver a tomar los cuestionarios calificados en este curso. Además, tienes la posibilidad de volver a tomar los cuestionarios de práctica de forma ilimitada y puedes revisar los videos y las lecturas tantas veces como necesites para dominar los conceptos de este curso.
#
# Ahora, antes de comenzar la prueba calificada, revise esta lista de errores de sintaxis comunes que los codificadores cometen al escribir código.
#
# Errores de sintaxis comunes:
# Errores de ortografía
#
# Sangrías incorrectas
#
# Caracteres clave faltantes o incorrectos:
#
# Tipos parentéticos - (curvo), [cuadrado], {rizado}
#
# Tipos de comillas: "doble recta" o "simple recta", "doble rizada" o "simple rizada"
#
# Caracteres de introducción de bloque, como dos puntos - :
#
# Desajustes en los tipos de datos
#
# Palabras reservadas de Python faltantes, incorrectamente utilizadas o mal ubicadas
#
# Uso incorrecto de mayúsculas y minúsculas: Python es un lenguaje que distingue entre mayúsculas y minúsculas

# %%
def difference(x, y):
    z = x - y
    return z


print(difference(5, 3))


((24 > 3*5) and (2*6 == 12))
# Out:
# 2
# True

# %%
x =   0
while x < 5:
    print("Not there yet, x=" + str(x))
    x = x + 1
print("x=" + str(x))
# Out:
# Not there yet, x=0
# Not there yet, x=1
# Not there yet, x=2
# Not there yet, x=3
# Not there yet, x=4
# x=5

# %% [markdown]
# **Revisión: ¿Qué es un bucle while?**
# Esta lectura contiene el código utilizado en los videos instructivos de
# ¿Qué es un bucle while?
#
#
#
# Introducción
# Esta lectura complementaria está organizada para coincidir con el contenido del video que sigue. Contiene el mismo código que se muestra en el siguiente video. Estos bloques de código le brindarán la oportunidad de ver cómo se escribe el código, le permitirán practicar su ejecución y pueden usarse como referencia para volver a consultarlos.
#
# Puede seguir la lectura mientras el instructor analiza el código o revisarlo después de ver el video.

# %% [markdown]
# **Anatomía de un bucle While**
# Un bucle while ejecutará código de forma continua en función del valor de una condición. Comienza con la palabra clave while, seguida de una comparación que se evaluará y luego dos puntos. En la siguiente línea se encuentra el bloque de código que se ejecutará, con sangría a la derecha. De forma similar a una declaración if , el código del cuerpo solo se ejecutará si la comparación se evalúa como verdadera. Sin embargo, lo que distingue a un bucle while es que este bloque de código seguirá ejecutándose mientras la declaración de evaluación sea verdadera. Una vez que la declaración ya no sea verdadera, el bucle sale y se ejecutará la siguiente línea de código.

# %%
def attempts(n):
    x = 1
    while x <= n:
        print("Attempt " + str(x))
        x += 1
    print("Done")

attempts(5)
# Out:
# Attempt 1
# Attempt 2
# Attempt 3
# Attempt 4
# Attempt 5
# Done

# %%
def attempts(n):
    x = 1
    while x <= n:
        print("Attempt " + str(x))
        x += 1
    print("Done")
attempts(5)
# Out:
# Attempt 1
# Attempt 2
# Attempt 3
# Attempt 4
# Attempt 5
# Done

# %%
username = get_username()
while not valid_username(username):
    print("Invalid username")
    username = get_username()

#This code will give an error because get_username is not defined

# %% [markdown]
# **Acerca de este código**
# A la variable nombre de usuario se le asigna el valor devuelto por la función get_username(). Se inicia el bucle while. El bucle continuará iterando mientras el valor de la variable nombre de usuario no sea válido. La función print() imprime el mensaje "Nombre de usuario no válido". A la variable nombre de usuario se le asigna el valor devuelto por la función get_username(). El bucle while finaliza.
#
# El código que proporcionó generará un error porque la función valid_username() no está definida. El bucle while intentará llamar a la función valid_username() en la línea 3, pero la función no existe.

# %%
def get_username():
    return input("Please enter a username: ")

def valid_username(username):
    return len(username) >= 5  # Considera válido cualquier nombre de usuario de al menos 5 caracteres

username = get_username()
while not valid_username(username):
    print("Invalid username")
    username = get_username()
# Out:
# Please enter a username: bur
# Invalid username
# Please enter a username: carlos
